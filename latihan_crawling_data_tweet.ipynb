# %% [markdown]
# **CRAWL DATA TWITTER PAKAI TWITTER API 29 JANUARI 2025**

# %%
# !pip install tweepy

# %%
import tweepy
import pandas as pd
import time

# Ganti dengan kredensial Anda
API_KEY = 'IfCAAHbVTQ8WeINHj0kSeGdWK'
API_SECRET_KEY = 'lA6P2O444pFSMs7Rnp9l6vvZGEpxd2706sLuGl00oVhGxf0p2Z'
ACCESS_TOKEN = '1868576488188248064-2q5X3TRyfyZqGAHKgrCF61IKZ0j1Zp'
ACCESS_TOKEN_SECRET = 'dn7YJARORYZoRHMv8F9vQTxo0VQCH7ljG8xSZ56CoEqiY'

# Autentikasi ke Twitter API
auth = tweepy.OAuth1UserHandler(API_KEY, API_SECRET_KEY, ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True)

# Using Tweepy Client for Twitter API v2
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAADJBygEAAAAAE3hfNpyzue7PR2VoN8IpyBRk%2FIk%3DYHTg3VQGnpf9nEwCkdYdylXAvu5CvXc4NmVKgnN326D6g5B580',
                       consumer_key=API_KEY,
                       consumer_secret=API_SECRET_KEY,
                       access_token=ACCESS_TOKEN,
                       access_token_secret=ACCESS_TOKEN_SECRET)

# Function to collect tweets using v2 API
def collect_tweets_v2(keyword, count=100):
    # Adjust count as needed; v2 has different rate limits
    tweets = client.search_recent_tweets(query=keyword,
                                          tweet_fields=['created_at', 'public_metrics'],
                                          user_fields=['username'],
                                          max_results=count,
                                          expansions=['author_id'])

    tweet_data = []
    for tweet in tweets.data:
        user = next((user for user in tweets.includes['users'] if user.id == tweet.author_id), None)
        tweet_data.append({
            'id': tweet.id,
            'created_at': tweet.created_at,
            'user': user.username if user else None,
            'text': tweet.text,
            'retweet_count': tweet.public_metrics['retweet_count'],
            'favorite_count': tweet.public_metrics['like_count']
        })

    return pd.DataFrame(tweet_data)

# Contoh penggunaan
keyword = 'makanbergizigratis'
count = 100  # Total number of tweets desired
batch_size = 100  # Number of tweets to fetch per request

tweet_df_list = []  # To store DataFrames from each batch

for i in range(0, count, batch_size):
    # Call collect_tweets_v2 with a smaller batch size
    try:
        df = collect_tweets_v2(keyword, count=batch_size)
        tweet_df_list.append(df)

        # Wait for a few seconds between requests
        time.sleep(5)
    except tweepy.TooManyRequests:
        print("Rate limit exceeded. Waiting for 15 minutes...")
        time.sleep(15 * 60)  # Wait for 15 minutes before retrying
        continue  # Retry the current batch

# Concatenate all the DataFrames into a single DataFrame
tweet_df = pd.concat(tweet_df_list, ignore_index=True)

# Simpan data ke file CSV
tweet_df.to_csv(f'{keyword}_tweets.csv', index=False)

print(tweet_df.head())
# Out:
# Rate limit exceeded. Waiting for 15 minutes...
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-2-96fb628928cf> in <cell line: 0>()
#      54     try:
# ---> 55         df = collect_tweets_v2(keyword, count=batch_size)
#      56         tweet_df_list.append(df)
#
# <ipython-input-2-96fb628928cf> in collect_tweets_v2(keyword, count)
#      24     # Adjust count as needed; v2 has different rate limits
# ---> 25     tweets = client.search_recent_tweets(query=keyword,
#      26                                           tweet_fields=['created_at', 'public_metrics'],
#
# /usr/local/lib/python3.11/dist-packages/tweepy/client.py in search_recent_tweets(self, query, user_auth, **params)
#    1269         params["query"] = query
# -> 1270         return self._make_request(
#    1271             "GET", "/2/tweets/search/recent", params=params,
#
# ...

# %%
tweet_df = pd.read_csv('/content/makanbergizigratis_tweets.csv')
tweet_df
# Out:
#                      id                 created_at             user  \
# 0   1884525721026232525  2025-01-29 08:55:19+00:00  Medianusan80251
# 1   1884525686616178798  2025-01-29 08:55:11+00:00  Medianusan80251
# 2   1884525652574978147  2025-01-29 08:55:03+00:00  Medianusan80251
# 3   1884508438396559605  2025-01-29 07:46:38+00:00  LarissaGoldGirl
# 4   1884508413595709904  2025-01-29 07:46:32+00:00  LarissaGoldGirl
# ..                  ...                        ...              ...
# 95  1884141932403978323  2025-01-28 07:30:17+00:00  Medianusan80251
# 96  1884141703063556560  2025-01-28 07:29:22+00:00  Medianusan80251
# 97  1884141667424620762  2025-01-28 07:29:13+00:00  Medianusan80251
# 98  1884141637720502484  2025-01-28 07:29:06+00:00  Medianusan80251
# 99  1884138518093652045  2025-01-28 07:16:42+00:00     bpomtabalong
#
#                                                  text  retweet_count  \
# 0   Kesehatan adalah fondasi utama mencapai kehidu...              0
# ...
